# %% [markdown]
# # Load Dependencies

# %%
from standardization import SPMS,add_o,add_o_o

# %% [markdown]
# # Standardization of molecular orientation

# %%
xyz_file='./data/lig_0_xtbopt.xyz'
spms = SPMS(xyz_file,key_atom_num=None,desc_n=40,desc_m=40)
spms._Standarlize_Geomertry()
new_positions=spms.new_positions
with open(xyz_file, 'r') as f:
    lines = f.read()
    atom_num=eval(lines.split('\n')[0])
    string=''
    string+=lines.split('\n')[0]
    string+='\n'
    string+=lines.split('\n')[1]
    string+='\n'
    for i in range(2,2+atom_num):
        lines_split=lines.split('\n')[i].split(' ')
        tem_index=[index  for index,i in enumerate(lines_split) if i !='']
        lines_split[tem_index[1]]='%.14f'%new_positions[i-2][0]
        lines_split[tem_index[2]]='%.14f'%new_positions[i-2][1]
        lines_split[tem_index[3]]='%.14f'%new_positions[i-2][2]
        tem_lines = lines_split[tem_index[0]]+add_o_o(lines_split[tem_index[0]],eval(lines.split('\n')[i].split(' ')[tem_index[1]]),new_positions[i-2][0],tem_index[1],tem_index[0])+\
                    lines_split[tem_index[1]]+add_o(eval(lines.split('\n')[i].split(' ')[tem_index[2]]),new_positions[i-2][1],tem_index[2],tem_index[1])+\
                    lines_split[tem_index[2]]+add_o(eval(lines.split('\n')[i].split(' ')[tem_index[3]]),new_positions[i-2][2],tem_index[3],tem_index[2])+\
                    lines_split[tem_index[3]]+'\n'
        string+=tem_lines
    print(string)
    with open('./data/lig_0_std.xyz','w') as fw:
        fw.writelines(string)
# Out:
# 83
#  energy: -102.047893144593 gnorm: 0.000388730567 xtb: 6.3.0 (preview)
# C         -3.24850639000000    1.10625040000000   -1.21245672000000
# C         -2.34532323000000    1.20545455000000    0.01636089000000
# C         -2.97123860000000    2.12945695000000    1.06565887000000
# C         -0.95850199000000    1.70551333000000   -0.30888136000000
# C         -0.80226549000000    2.75239009000000   -1.19927249000000
# C          0.44595900000000    3.29575911000000   -1.45983252000000
# C          0.62828430000000    4.39712273000000   -2.47521917000000
# C          0.27189968000000    3.89445147000000   -3.87583839000000
# C         -0.20438330000000    5.62796885000000   -2.11213634000000
# C          1.52318246000000    2.80714025000000   -0.74655907000000
# C          1.40962212000000    1.77513293000000    0.18327452000000
# C          2.69023167000000    1.51919764000000    0.96582914000000
# C          2.91023266000000    0.17462912000000    1.65825958000000
# C          2.81380081000000    2.63695116000000    2.01139527000000
# C          0.15740940000000    1.17602462000000    0.35462356000000
# C          0.00000100000000    0.00000100000000    1.24805258000000
# C          0.02065264000000   -1.30438585000000    0.74070068000000
# P         -0.36745479000000   -1.43455373000000   -1.08049796000000
# C          1.27456088000000   -1.94856131000000   -1.91513946000000
# C          0.99875486000000   -2.35656591000000   -3.36300856000000
# C          2.09033092000000   -3.01816424000000   -1.20106721000000
# C          2.07753569000000   -0.64512340000000   -1.97157129000000
# C         -1.62462968000000   -2.89388912000000   -1.23367981000000
# C         -2.40817736000000   -2.53758500000000   -2.50579109000000
# C         -2.59505993000000   -2.79633037000000   -0.05435563000000
# C         -1.14503195000000   -4.33744720000000   -1.36616153000000
# C          0.10805509000000   -2.36490675000000    1.66205480000000
