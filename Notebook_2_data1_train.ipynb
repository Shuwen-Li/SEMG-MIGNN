# %% [markdown]
# This notebook is a tutorial for training and prediction in data1.

# %% [markdown]
# # Load Dependencies

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

import numpy as np
import tensorflow as tf
from script.MIGNN_model import Graph_DataLoader,MIGNN_model1
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
# Out:
# 2022-09-13 10:57:36.721101: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-13 10:57:37.023672: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-13 10:57:37.023934: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-13 10:57:37.028286: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-09-13 10:57:37.028308: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# # Load Steric and Electronic Information

# %%
react_spms = np.load('./data1/run_data/data1_SEMG_MIGNN_react_spms.npy')
react_elec = np.load('./data1/run_data/data1_SEMG_MIGNN_react_elec.npy')
labels = np.load('./data1/run_data/data1_SEMG_MIGNN_labels.npy')
label_std = np.load('./data1/run_data/data1_SEMG_MIGNN_label_std.npy')

# %% [markdown]
# # Train Model

# %%
batch_size = 128
np.random.seed(2021)
shuffle = np.array(list(range(len(react_spms))))
np.random.shuffle(shuffle)
train_index = shuffle[:int(0.7*len(react_spms))]
val_index = shuffle[int(0.7*len(react_spms)):]
spms_train,elec_train,y_train = react_spms[train_index],react_elec[train_index],label_std[train_index]
spms_val,elec_val,y_val = react_spms[val_index],react_elec[val_index],label_std[val_index]

train_gen = Graph_DataLoader(spms_train,elec_train,y_train,batch_size=batch_size)
valid_gen = Graph_DataLoader(spms_val,elec_val,y_val,batch_size=batch_size)
valid_gen_predict = Graph_DataLoader(spms_val,elec_val,y_val,batch_size=batch_size,predict=True)
opt = tf.keras.optimizers.Adam()

# %%
model = MIGNN_model1(107, 36, 56, 18,linear_depth=4,atom_attention=1,inter_attention=1,
                    end_attention=1,hidden_size=128,final_act='none')

model.compile(optimizer=opt,loss='mse')
checkpoint = tf.train.Checkpoint(myAwesomeModel=model)
EPOCHS = 100
for epoch in range(EPOCHS):
    hist = model.fit(train_gen,validation_data=valid_gen)
    path = checkpoint.save('./data1/run_data/data1_random.ckpt')
    print("model saved to %s" % path)
# Out:
# 22/22 [==============================] - 13s 491ms/step - loss: 0.0738 - val_loss: 0.0816
# model saved to ./data1/run_data/data1_random.ckpt-1
# 22/22 [==============================] - 10s 465ms/step - loss: 0.0561 - val_loss: 0.0631
# model saved to ./data1/run_data/data1_random.ckpt-2
# 22/22 [==============================] - 10s 462ms/step - loss: 0.0387 - val_loss: 0.0866
# model saved to ./data1/run_data/data1_random.ckpt-3
# 22/22 [==============================] - 10s 457ms/step - loss: 0.0257 - val_loss: 0.1005
# model saved to ./data1/run_data/data1_random.ckpt-4
# 22/22 [==============================] - 10s 458ms/step - loss: 0.0204 - val_loss: 0.0766
# model saved to ./data1/run_data/data1_random.ckpt-5
# 22/22 [==============================] - 10s 460ms/step - loss: 0.0145 - val_loss: 0.0748
# model saved to ./data1/run_data/data1_random.ckpt-6
# 22/22 [==============================] - 10s 457ms/step - loss: 0.0122 - val_loss: 0.0661
# model saved to ./data1/run_data/data1_random.ckpt-7
# 22/22 [==============================] - 10s 456ms/step - loss: 0.0107 - val_loss: 0.0387
# model saved to ./data1/run_data/data1_random.ckpt-8
# 22/22 [==============================] - 10s 466ms/step - loss: 0.0085 - val_loss: 0.0377
# model saved to ./data1/run_data/data1_random.ckpt-9
# 22/22 [==============================] - 10s 460ms/step - loss: 0.0073 - val_loss: 0.0218
# model saved to ./data1/run_data/data1_random.ckpt-10
# 22/22 [==============================] - 10s 466ms/step - loss: 0.0067 - val_loss: 0.0259
# model saved to ./data1/run_data/data1_random.ckpt-11
# 22/22 [==============================] - 10s 462ms/step - loss: 0.0059 - val_loss: 0.0180
# model saved to ./data1/run_data/data1_random.ckpt-12
# 22/22 [==============================] - 10s 456ms/step - loss: 0.0049 - val_loss: 0.0172
# model saved to ./data1/run_data/data1_random.ckpt-13
# 22/22 [==============================] - 10s 453ms/step - loss: 0.0051 - val_loss: 0.0105
# model saved to ./data1/run_data/data1_random.ckpt-14
# 22/22 [==============================] - 10s 454ms/step - loss: 0.0046 - val_loss: 0.0091
# model saved to ./data1/run_data/data1_random.ckpt-15
# 22/22 [==============================] - 10s 466ms/step - loss: 0.0040 - val_loss: 0.0076
# model saved to ./data1/run_data/data1_random.ckpt-16
# 22/22 [==============================] - 10s 463ms/step - loss: 0.0035 - val_loss: 0.0063
# model saved to ./data1/run_data/data1_random.ckpt-17
# 22/22 [==============================] - 10s 463ms/step - loss: 0.0031 - val_loss: 0.0073
# model saved to ./data1/run_data/data1_random.ckpt-18
# 22/22 [==============================] - 10s 458ms/step - loss: 0.0028 - val_loss: 0.0063
# model saved to ./data1/run_data/data1_random.ckpt-19
# 22/22 [==============================] - 10s 457ms/step - loss: 0.0027 - val_loss: 0.0053
# model saved to ./data1/run_data/data1_random.ckpt-20
# 22/22 [==============================] - 10s 454ms/step - loss: 0.0023 - val_loss: 0.0059
# model saved to ./data1/run_data/data1_random.ckpt-21
# 22/22 [==============================] - 10s 458ms/step - loss: 0.0023 - val_loss: 0.0054
# model saved to ./data1/run_data/data1_random.ckpt-22
# 22/22 [==============================] - 10s 467ms/step - loss: 0.0023 - val_loss: 0.0055
# model saved to ./data1/run_data/data1_random.ckpt-23
# 22/22 [==============================] - 10s 463ms/step - loss: 0.0019 - val_loss: 0.0052
# model saved to ./data1/run_data/data1_random.ckpt-24
# 22/22 [==============================] - 10s 460ms/step - loss: 0.0020 - val_loss: 0.0051
# model saved to ./data1/run_data/data1_random.ckpt-25
# 22/22 [==============================] - 10s 461ms/step - loss: 0.0018 - val_loss: 0.0052
# model saved to ./data1/run_data/data1_random.ckpt-26
# 22/22 [==============================] - 10s 455ms/step - loss: 0.0016 - val_loss: 0.0050
# model saved to ./data1/run_data/data1_random.ckpt-27
# 22/22 [==============================] - 10s 456ms/step - loss: 0.0015 - val_loss: 0.0049
# model saved to ./data1/run_data/data1_random.ckpt-28
# 22/22 [==============================] - 10s 459ms/step - loss: 0.0014 - val_loss: 0.0050
# model saved to ./data1/run_data/data1_random.ckpt-29
# 22/22 [==============================] - 12s 532ms/step - loss: 0.0015 - val_loss: 0.0048
# model saved to ./data1/run_data/data1_random.ckpt-30
# 22/22 [==============================] - 13s 601ms/step - loss: 0.0013 - val_loss: 0.0051
# model saved to ./data1/run_data/data1_random.ckpt-31
# 22/22 [==============================] - 13s 597ms/step - loss: 0.0011 - val_loss: 0.0045
# model saved to ./data1/run_data/data1_random.ckpt-32
# 22/22 [==============================] - 13s 597ms/step - loss: 0.0012 - val_loss: 0.0044
# model saved to ./data1/run_data/data1_random.ckpt-33
# 22/22 [==============================] - 13s 604ms/step - loss: 9.8886e-04 - val_loss: 0.0043
# model saved to ./data1/run_data/data1_random.ckpt-34
# 22/22 [==============================] - 13s 607ms/step - loss: 8.9706e-04 - val_loss: 0.0043
-04 - val_loss: 0.0036
# model saved to ./data1/run_data/data1_random.ckpt-90
# 22/22 [==============================] - 10s 442ms/step - loss: 2.4634e-04 - val_loss: 0.0035
# model saved to ./data1/run_data/data1_random.ckpt-91
# 22/22 [==============================] - 10s 441ms/step - loss: 2.4587e-04 - val_loss: 0.0036
# model saved to ./data1/run_data/data1_random.ckpt-92
# 22/22 [==============================] - 10s 457ms/step - loss: 2.8012e-04 - val_loss: 0.0038
# model saved to ./data1/run_data/data1_random.ckpt-93
# 22/22 [==============================] - 10s 454ms/step - loss: 3.1967e-04 - val_loss: 0.0037
# model saved to ./data1/run_data/data1_random.ckpt-94
# 22/22 [==============================] - 10s 450ms/step - loss: 2.3349e-04 - val_loss: 0.0035
# model saved to ./data1/run_data/data1_random.ckpt-95
# 22/22 [==============================] - 10s 444ms/step - loss: 2.0717e-04 - val_loss: 0.0036
# model saved to ./data1/run_data/data1_random.ckpt-96
# 22/22 [==============================] - 10s 442ms/step - loss: 2.3316e-04 - val_loss: 0.0036
# model saved to ./data1/run_data/data1_random.ckpt-97
# 22/22 [==============================] - 10s 443ms/step - loss: 2.5301e-04 - val_loss: 0.0035
# model saved to ./data1/run_data/data1_random.ckpt-98
# 22/22 [==============================] - 10s 443ms/step - loss: 2.2236e-04 - val_loss: 0.0036
# model saved to ./data1/run_data/data1_random.ckpt-99
# 22/22 [==============================] - 10s 451ms/step - loss: 2.4866e-04 - val_loss: 0.0037
# model saved to ./data1/run_data/data1_random.ckpt-100

# %%
new_model = MIGNN_model1(107, 36, 56, 18,linear_depth=4,atom_attention=1,inter_attention=1,
                    end_attention=0,hidden_size=128,final_act='none')
new_model.compile(optimizer=opt,loss='mse')

checkpoint = tf.train.Checkpoint(myAwesomeModel=new_model) 
checkpoint.restore('./data1/run_data/data1_random.ckpt-100') # 46
_ = new_model.fit(valid_gen,epochs=1)
y_pred = new_model.predict(valid_gen_predict)
y_val=label_std[val_index]
y_val=y_val*(labels.max()-labels.min())+labels.min()
y_pred=y_pred*(labels.max()-labels.min())+labels.min()
# Out:
# 10/10 [==============================] - 6s 348ms/step - loss: 0.0060

# %% [markdown]
# # Results

# %%
sns.set(style='darkgrid')
fig = plt.figure(figsize=(11,11),facecolor='white',    
           edgecolor='black')
plt.scatter(y_val,y_pred,s=250, c='royalblue', label="samples",alpha=0.6,edgecolors='navy')#royalblue
plt.plot([-20,120],[-20,120],c='black')
plt.xlim(-10,110)
plt.ylim(-10,110)
x_major_locator=MultipleLocator(20)
y_major_locator=MultipleLocator(20)
ax=plt.gca()
ax.set_facecolor('mistyrose')
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
plt.xlabel("Observed Yield(%)",fontsize=36)
plt.ylabel("Predicted Yield(%)",fontsize=36)
plt.tick_params(labelsize=30)
plt.text(2,82,'RMSE = %.3f'%(mean_squared_error(y_val,y_pred))**(0.5),fontsize=30)
plt.text(2,90,'R$^2$ = %.3f'%r2_score(y_val,y_pred),fontsize=30)
plt.subplots_adjust(left=0.15, right=0.95, top=0.9, bottom=0.1)
plt.show()

# %%
np.save('./result/data1_SEMG_MIGNN_y_val.npy',y_val)
np.save('./result/data1_SEMG_MIGNN_y_pred.npy',y_pred)
